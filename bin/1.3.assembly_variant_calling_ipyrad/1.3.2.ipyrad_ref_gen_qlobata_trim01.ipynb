# %% [markdown]
# # Ensamble genoma de referencia
#
# ### Genoma de referencia: _Quercus lobata_
#
# ### Prueba con Trimmomatic01
#
# ### Lecturas de *Quercus macdougallii*
#
# ### Parámetros:

# %%
#conda install ipyrad -c ipyrad
#conda install toytree -c eaton-lab
#conda install entrez-direct -c bioconda
#conda install sratools -c bioconda

# %%
#Importar librerias
import ipyrad as ip
import ipyparallel as ipp

# %%
## Crear un objeto Ensamble llamado data1. 
ref_gen_qlob_trim01 = ip.Assembly("ref_gen_qlob_trim01")
# Out:
# New Assembly: ref_gen_qlob_trim01

# %%
## prints the parameters to the screen
ref_gen_qlob_trim01.get_params()
# Out:
# 0   assembly_name               ref_gen_qlob_trim01
# 1   project_dir                 /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/bin
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    rad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# ...

# %%
## setting/modifying parameters for this Assembly object
ref_gen_qlob_trim01.set_params('project_dir', '../data/1.3.assemble_variant_calling/1.3.2.ipyrad/ref_gen_qlob_trim01')
ref_gen_qlob_trim01.set_params('sorted_fastq_path', "../data/1.1.filter/*trim01.fastq.gz")
ref_gen_qlob_trim01.set_params('assembly_method', "reference")
ref_gen_qlob_trim01.set_params('reference_sequence', '../data/reference_genomes/Qlobata.v3.0.RptMsk4.0.6.on-RptMdl1.0.8.softmasked.fasta')
ref_gen_qlob_trim01.set_params('datatype', 'ddrad')
ref_gen_qlob_trim01.set_params('output_formats', ['p', 's', 'k', 'g', 'v'])

## prints the parameters to the screen
ref_gen_qlob_trim01.get_params()
# Out:
# 0   assembly_name               ref_gen_qlob_trim01
# 1   project_dir                 /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/data/1.3.assemble_variant_calling/1.3.2.ipyrad/ref_gen_qlob_trim01
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path           /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/data/1.1.filter/*trim01.fastq.gz
# 5   assembly_method             reference
# 6   reference_sequence          /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/data/reference_genomes/Qlobata.v3.0.RptMsk4.0.6.on-RptMdl1.0.8.softmasked.fasta
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# ...

# %%
## run step 1 to create Samples objects
ref_gen_qlob_trim01.run("1", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:01:17 | loading reads        | s1 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw
# CR_01_S115.trim01      1     659102
# CR_02_S127.trim01      1     667825
# CR_03_S139.trim01      1     593730
# CR_04_S151.trim01      1     662193
# CR_05_S163.trim01      1     639116
# CR_06_S175.trim01      1     582940
# CR_07_S186.trim01      1     622219
# CR_08_S104.trim01      1     626249
# CR_09_S116.trim01      1     633641
# CR_10_S128.trim01      1     602334
# CY_01_S170.trim01      1     664879
# CY_02_S181.trim01      1     747758
# CY_03_S99.trim01       1     582526
# CY_04_S111.trim01      1     672096
# CY_05_S123.trim01      1     734743
# CY_06_S135.trim01      1     693776
# CY_07_S147.trim01      1     749671
# CY_08_S159.trim01      1     738227
# CY_09_S171.trim01      1     550556
# CY_10_S182.trim01      1     713833
# CZ_01_S100.trim01      1     719616
# CZ_02_S112.trim01      1     600955
# CZ_03_S124.trim01      1     692633
# CZ_04_S136.trim01      1     763773
# CZ_05_S148.trim01      1     755235
# ...

# %%
## run step 2 to create Samples objects
ref_gen_qlob_trim01.run("2", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:05:12 | processing reads     | s2 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw  reads_passed_filter
# CR_01_S115.trim01      2     659102               659067
# CR_02_S127.trim01      2     667825               667765
# CR_03_S139.trim01      2     593730               593685
# CR_04_S151.trim01      2     662193               662088
# CR_05_S163.trim01      2     639116               639043
# CR_06_S175.trim01      2     582940               582878
# CR_07_S186.trim01      2     622219               622186
# CR_08_S104.trim01      2     626249               626210
# CR_09_S116.trim01      2     633641               633619
# CR_10_S128.trim01      2     602334               602307
# CY_01_S170.trim01      2     664879               664863
# CY_02_S181.trim01      2     747758               747688
# CY_03_S99.trim01       2     582526               582467
# CY_04_S111.trim01      2     672096               672083
# CY_05_S123.trim01      2     734743               734669
# ...

# %%
## run step 3
ref_gen_qlob_trim01.run("3", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:02 | indexing reference   | s3 |
# [####################] 100% 0:14:14 | dereplicating        | s3 |
# [####################] 100% 0:43:29 | mapping reads        | s3 |
# [####################] 100% 0:08:10 | building clusters    | s3 |
# [####################] 100% 0:00:11 | calc cluster stats   | s3 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      3     659102               659067               562213
# CR_02_S127.trim01      3     667825               667765               540692
# CR_03_S139.trim01      3     593730               593685               478841
# CR_04_S151.trim01      3     662193               662088               541574
# CR_05_S163.trim01      3     639116               639043               509144
# CR_06_S175.trim01      3     582940               582878               505359
# CR_07_S186.trim01      3     622219               622186               524496
# CR_08_S104.trim01      3     626249               626210               495665
# CR_09_S116.trim01      3     633641               633619               524921
# CR_10_S128.trim01      3     602334               602307               478152
# CY_01_S170.trim01      3     664879               664863               622159
# ...

# %%
## run step 4
ref_gen_qlob_trim01.run("4", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:05:02 | inferring [H, E]     | s4 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      4     659102               659067               562213
# CR_02_S127.trim01      4     667825               667765               540692
# CR_03_S139.trim01      4     593730               593685               478841
# CR_04_S151.trim01      4     662193               662088               541574
# CR_05_S163.trim01      4     639116               639043               509144
# CR_06_S175.trim01      4     582940               582878               505359
# CR_07_S186.trim01      4     622219               622186               524496
# CR_08_S104.trim01      4     626249               626210               495665
# CR_09_S116.trim01      4     633641               633619               524921
# CR_10_S128.trim01      4     602334               602307               478152
# CY_01_S170.trim01      4     664879               664863               622159
# ...

# %%
## run step 5
ref_gen_qlob_trim01.run("5", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:11 | calculating depths   | s5 |
# [####################] 100% 0:02:23 | chunking clusters    | s5 |
# [####################] 100% 0:29:19 | consens calling      | s5 |
# [####################] 100% 0:00:39 | indexing alleles     | s5 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      5     659102               659067               562213
# CR_02_S127.trim01      5     667825               667765               540692
# CR_03_S139.trim01      5     593730               593685               478841
# CR_04_S151.trim01      5     662193               662088               541574
# CR_05_S163.trim01      5     639116               639043               509144
# CR_06_S175.trim01      5     582940               582878               505359
# CR_07_S186.trim01      5     622219               622186               524496
# CR_08_S104.trim01      5     626249               626210               495665
# CR_09_S116.trim01      5     633641               633619               524921
# CR_10_S128.trim01      5     602334               602307               478152
# CY_01_S170.trim01      5     664879               664863               622159
# ...

# %%
## run step 6
ref_gen_qlob_trim01.run("6",auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:12 | concatenating bams   | s6 |
# [####################] 100% 0:00:04 | fetching regions     | s6 |
# [####################] 100% 0:00:25 | building database    | s6 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      6     659102               659067               562213
# CR_02_S127.trim01      6     667825               667765               540692
# CR_03_S139.trim01      6     593730               593685               478841
# CR_04_S151.trim01      6     662193               662088               541574
# CR_05_S163.trim01      6     639116               639043               509144
# CR_06_S175.trim01      6     582940               582878               505359
# CR_07_S186.trim01      6     622219               622186               524496
# CR_08_S104.trim01      6     626249               626210               495665
# CR_09_S116.trim01      6     633641               633619               524921
# CR_10_S128.trim01      6     602334               602307               478152
# CY_01_S170.trim01      6     664879               664863               622159
# ...

# %%
## create a branch for outputs with min_samples = 3 (lots of missing data)
ref_gen_qlob_trim01_1 = ref_gen_qlob_trim01.branch("ref_gen_qlob_trim01_1")
ref_gen_qlob_trim01_1.set_params("clust_threshold", "0.70")
ref_gen_qlob_trim01_1.set_params('pop_assign_file', '../data/1.3.assemble_variant_calling/1.3.2.ipyrad/popmap_8sites_2zones_trim01.txt')

ref_gen_qlob_trim01_1.run("7", auto=True, force=True)

## create a branch for outputs with min_samples = 3 (lots of missing data)
ref_gen_qlob_trim01_2 = ref_gen_qlob_trim01.branch("ref_gen_qlob_trim01_2")
ref_gen_qlob_trim01_2.set_params("min_samples_locus", 79)
ref_gen_qlob_trim01_2.set_params("clust_threshold", "0.90")

ref_gen_qlob_trim01_2.run("7", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:18 | applying filters     | s7 |
# [####################] 100% 0:00:04 | building arrays      | s7 |
# [####################] 100% 0:00:02 | writing conversions  | s7 |
# [####################] 100% 0:00:07 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:05 | writing vcf output   | s7 |
# Parallel connection closed.
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:18 | applying filters     | s7 |
# [####################] 100% 0:00:04 | building arrays      | s7 |
# [####################] 100% 0:00:02 | writing conversions  | s7 |
# [####################] 100% 0:00:06 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:04 | writing vcf output   | s7 |
# Parallel connection closed.

# %%
ref_gen_qlob_trim01_1.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      6     659102               659067               562213
# CR_02_S127.trim01      6     667825               667765               540692
# CR_03_S139.trim01      6     593730               593685               478841
# CR_04_S151.trim01      6     662193               662088               541574
# CR_05_S163.trim01      6     639116               639043               509144
# CR_06_S175.trim01      6     582940               582878               505359
# CR_07_S186.trim01      6     622219               622186               524496
# CR_08_S104.trim01      6     626249               626210               495665
# CR_09_S116.trim01      6     633641               633619               524921
# CR_10_S128.trim01      6     602334               602307               478152
# CY_01_S170.trim01      6     664879               664863               622159
# ...

# %%
ref_gen_qlob_trim01_2.stats
# Out:
#                    state  reads_raw  reads_passed_filter  refseq_mapped_reads  \
# CR_01_S115.trim01      6     659102               659067               562213
# CR_02_S127.trim01      6     667825               667765               540692
# CR_03_S139.trim01      6     593730               593685               478841
# CR_04_S151.trim01      6     662193               662088               541574
# CR_05_S163.trim01      6     639116               639043               509144
# CR_06_S175.trim01      6     582940               582878               505359
# CR_07_S186.trim01      6     622219               622186               524496
# CR_08_S104.trim01      6     626249               626210               495665
# CR_09_S116.trim01      6     633641               633619               524921
# CR_10_S128.trim01      6     602334               602307               478152
# CY_01_S170.trim01      6     664879               664863               622159
# ...
