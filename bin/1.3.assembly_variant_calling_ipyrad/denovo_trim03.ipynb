# %% [markdown]
# # Ensamble *De novo*
#
# ### Prueba con Trimmomatic03
#
# ### Lecturas de *Quercus macdougallii*
#
# ### Parámetros:

# %%
#conda install ipyrad -c ipyrad
#conda install toytree -c eaton-lab
#conda install entrez-direct -c bioconda
#conda install sratools -c bioconda

# %%
#Importar librerias
import ipyrad as ip
import ipyparallel as ipp

# %%
## Crear un objeto Ensamble llamado data1. 
denovo_trim03 = ip.Assembly("denovo_trim03")
# Out:
# New Assembly: denovo_trim03

# %%
## prints the parameters to the screen
denovo_trim03.get_params()
# Out:
# 0   assembly_name               denovo_trim03
# 1   project_dir                 /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/bin
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    rad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# ...

# %%
## setting/modifying parameters for this Assembly object
denovo_trim03.set_params('project_dir', '../data/1.3.assemble_variant_calling/1.3.2.ipyrad/denovo_trim03')
denovo_trim03.set_params('sorted_fastq_path', "../data/1.1.filter/*trim03.fastq.gz")
denovo_trim03.set_params('assembly_method', 'denovo')
denovo_trim03.set_params('datatype', 'ddrad')
denovo_trim03.set_params('output_formats', ['p', 's', 'k', 'g', 'v'])

## prints the parameters to the screen
denovo_trim03.get_params()
# Out:
# 0   assembly_name               denovo_trim03
# 1   project_dir                 /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/data/1.3.assemble_variant_calling/1.3.2.ipyrad/denovo_trim03
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path           /media/jaz/n311y_pc/Bioinformatic/Qmacdougallii_genomics_and_environment/data/1.1.filter/*trim03.fastq.gz
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# ...

# %%
## run step 1 to create Samples objects
denovo_trim03.run("1", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:54 | loading reads        | s1 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw
# CR_01_S115.trim03      1     637962
# CR_02_S127.trim03      1     646858
# CR_03_S139.trim03      1     574664
# CR_04_S151.trim03      1     641301
# CR_05_S163.trim03      1     619059
# CR_06_S175.trim03      1     564596
# CR_07_S186.trim03      1     601967
# CR_08_S104.trim03      1     604989
# CR_09_S116.trim03      1     612353
# CR_10_S128.trim03      1     581934
# CY_01_S170.trim03      1     643060
# CY_02_S181.trim03      1     721872
# CY_03_S99.trim03       1     563193
# CY_04_S111.trim03      1     649564
# CY_05_S123.trim03      1     710832
# CY_06_S135.trim03      1     671712
# CY_07_S147.trim03      1     725808
# CY_08_S159.trim03      1     714592
# CY_09_S171.trim03      1     533188
# CY_10_S182.trim03      1     689992
# CZ_01_S100.trim03      1     695419
# CZ_02_S112.trim03      1     581235
# CZ_03_S124.trim03      1     668873
# CZ_04_S136.trim03      1     739403
# CZ_05_S148.trim03      1     730486
# ...

# %%
## run step 2 to create Samples objects
denovo_trim03.run("2", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:04:10 | processing reads     | s2 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw  reads_passed_filter
# CR_01_S115.trim03      2     637962               637946
# CR_02_S127.trim03      2     646858               646822
# CR_03_S139.trim03      2     574664               574644
# CR_04_S151.trim03      2     641301               641250
# CR_05_S163.trim03      2     619059               619011
# CR_06_S175.trim03      2     564596               564564
# CR_07_S186.trim03      2     601967               601950
# CR_08_S104.trim03      2     604989               604973
# CR_09_S116.trim03      2     612353               612337
# CR_10_S128.trim03      2     581934               581914
# CY_01_S170.trim03      2     643060               643049
# CY_02_S181.trim03      2     721872               721848
# CY_03_S99.trim03       2     563193               563166
# CY_04_S111.trim03      2     649564               649556
# CY_05_S123.trim03      2     710832               710794
# ...

# %%
## run step 3
denovo_trim03.run("3", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:03:00 | dereplicating        | s3 |
# [####################] 100% 0:21:23 | clustering/mapping   | s3 |
# [####################] 100% 0:00:01 | building clusters    | s3 |
# [####################] 100% 0:00:00 | chunking clusters    | s3 |
# [####################] 100% 2:09:06 | aligning clusters    | s3 |
# [####################] 100% 0:00:24 | concat clusters      | s3 |
# [####################] 100% 0:00:10 | calc cluster stats   | s3 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      3     637962               637946           59636
# CR_02_S127.trim03      3     646858               646822           80355
# CR_03_S139.trim03      3     574664               574644           70216
# CR_04_S151.trim03      3     641301               641250           75539
# CR_05_S163.trim03      3     619059               619011           73561
# CR_06_S175.trim03      3     564596               564564           55945
# CR_07_S186.trim03      3     601967               601950           71429
# CR_08_S104.trim03      3     604989               604973           87862
# CR_09_S116.trim03      3     612353               612337           80073
# CR_10_S128.trim03      3     581934               581914           95572
# CY_01_S170.trim03      3     643060               643049           47186
# CY_02_S181.trim03      3     721872               721848           38688
# ...

# %%
## run step 4
denovo_trim03.run("4", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:05:13 | inferring [H, E]     | s4 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      4     637962               637946           59636
# CR_02_S127.trim03      4     646858               646822           80355
# CR_03_S139.trim03      4     574664               574644           70216
# CR_04_S151.trim03      4     641301               641250           75539
# CR_05_S163.trim03      4     619059               619011           73561
# CR_06_S175.trim03      4     564596               564564           55945
# CR_07_S186.trim03      4     601967               601950           71429
# CR_08_S104.trim03      4     604989               604973           87862
# CR_09_S116.trim03      4     612353               612337           80073
# CR_10_S128.trim03      4     581934               581914           95572
# CY_01_S170.trim03      4     643060               643049           47186
# CY_02_S181.trim03      4     721872               721848           38688
# ...

# %%
## run step 5
denovo_trim03.run("5", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:11 | calculating depths   | s5 |
# [####################] 100% 0:01:03 | chunking clusters    | s5 |
# [####################] 100% 0:21:50 | consens calling      | s5 |
# [####################] 100% 0:00:20 | indexing alleles     | s5 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      5     637962               637946           59636
# CR_02_S127.trim03      5     646858               646822           80355
# CR_03_S139.trim03      5     574664               574644           70216
# CR_04_S151.trim03      5     641301               641250           75539
# CR_05_S163.trim03      5     619059               619011           73561
# CR_06_S175.trim03      5     564596               564564           55945
# CR_07_S186.trim03      5     601967               601950           71429
# CR_08_S104.trim03      5     604989               604973           87862
# CR_09_S116.trim03      5     612353               612337           80073
# CR_10_S128.trim03      5     581934               581914           95572
# CY_01_S170.trim03      5     643060               643049           47186
# CY_02_S181.trim03      5     721872               721848           38688
# ...

# %%
## run step 6
denovo_trim03.run("6",auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:05 | concatenating inputs | s6 |
# [####################] 100% 0:00:40 | clustering across    | s6 |
# [####################] 100% 0:00:04 | building clusters    | s6 |
# [####################] 100% 0:03:15 | aligning clusters    | s6 |
# Parallel connection closed.

# %%
denovo_trim03.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      6     637962               637946           59636
# CR_02_S127.trim03      6     646858               646822           80355
# CR_03_S139.trim03      6     574664               574644           70216
# CR_04_S151.trim03      6     641301               641250           75539
# CR_05_S163.trim03      6     619059               619011           73561
# CR_06_S175.trim03      6     564596               564564           55945
# CR_07_S186.trim03      6     601967               601950           71429
# CR_08_S104.trim03      6     604989               604973           87862
# CR_09_S116.trim03      6     612353               612337           80073
# CR_10_S128.trim03      6     581934               581914           95572
# CY_01_S170.trim03      6     643060               643049           47186
# CY_02_S181.trim03      6     721872               721848           38688
# ...

# %%
## create a branch for outputs with min_samples = 3 (lots of missing data)
denovo_trim03_1 = denovo_trim03.branch("denovo_trim03_1")
denovo_trim03_1.set_params('pop_assign_file', '../data/1.3.assemble_variant_calling/1.3.2.ipyrad/popmap_8sites_2zones_trim03.txt')
denovo_trim03_1.set_params("clust_threshold", "0.80")
denovo_trim03_1.run("7", auto=True, force=True)

## create a branch for outputs with min_samples = 3 (lots of missing data)
denovo_trim03_2 = denovo_trim03.branch("denovo_trim03_2")
denovo_trim03_2.set_params("min_samples_locus", 79)
denovo_trim03_2.set_params("clust_threshold", "0.90")
denovo_trim03_2.run("7", auto=True, force=True)
# Out:
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:15 | applying filters     | s7 |
# [####################] 100% 0:00:02 | building arrays      | s7 |
# [####################] 100% 0:00:01 | writing conversions  | s7 |
# [####################] 100% 0:00:04 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:02 | writing vcf output   | s7 |
# Parallel connection closed.
# Parallel connection | n311: 12 cores
# [####################] 100% 0:00:15 | applying filters     | s7 |
# [####################] 100% 0:00:03 | building arrays      | s7 |
# [####################] 100% 0:00:01 | writing conversions  | s7 |
# [####################] 100% 0:00:04 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:02 | writing vcf output   | s7 |
# Parallel connection closed.

# %%
denovo_trim03_1.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      6     637962               637946           59636
# CR_02_S127.trim03      6     646858               646822           80355
# CR_03_S139.trim03      6     574664               574644           70216
# CR_04_S151.trim03      6     641301               641250           75539
# CR_05_S163.trim03      6     619059               619011           73561
# CR_06_S175.trim03      6     564596               564564           55945
# CR_07_S186.trim03      6     601967               601950           71429
# CR_08_S104.trim03      6     604989               604973           87862
# CR_09_S116.trim03      6     612353               612337           80073
# CR_10_S128.trim03      6     581934               581914           95572
# CY_01_S170.trim03      6     643060               643049           47186
# CY_02_S181.trim03      6     721872               721848           38688
# ...

# %%
denovo_trim03_2.stats
# Out:
#                    state  reads_raw  reads_passed_filter  clusters_total  \
# CR_01_S115.trim03      6     637962               637946           59636
# CR_02_S127.trim03      6     646858               646822           80355
# CR_03_S139.trim03      6     574664               574644           70216
# CR_04_S151.trim03      6     641301               641250           75539
# CR_05_S163.trim03      6     619059               619011           73561
# CR_06_S175.trim03      6     564596               564564           55945
# CR_07_S186.trim03      6     601967               601950           71429
# CR_08_S104.trim03      6     604989               604973           87862
# CR_09_S116.trim03      6     612353               612337           80073
# CR_10_S128.trim03      6     581934               581914           95572
# CY_01_S170.trim03      6     643060               643049           47186
# CY_02_S181.trim03      6     721872               721848           38688
# ...
